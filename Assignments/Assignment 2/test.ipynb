# %%
# import libraries
import numpy as np
from scipy.optimize import minimize
from scipy import linalg
import matplotlib.pyplot as plt
import cv2 as cv

# %%
img1 = cv.imread('./Q3_images/img1.ppm')
img5 = cv.imread('./Q3_images/img5.ppm')
assert img1 is not None
assert img5 is not None

# img5 = img5[:, 200:600, :]

img1_gray = cv.cvtColor(img1, cv.COLOR_BGR2GRAY)
img5_gray = cv.cvtColor(img5, cv.COLOR_BGR2GRAY)
img1 = cv.cvtColor(img1, cv.COLOR_BGR2RGB)
img5 = cv.cvtColor(img5, cv.COLOR_BGR2RGB)

def nothing(x):
    pass

cv.namedWindow('Trackbar')
cv.resizeWindow('Trackbar', 720, 540)

cv.createTrackbar('contrast threshold', 'Trackbar', 10, 100, nothing)
cv.createTrackbar('edge threshold', 'Trackbar', 1, 1000, nothing)
cv.createTrackbar('sigma', 'Trackbar', 10, 50, nothing)

while (True):
    contrast = cv.getTrackbarPos('contrast threshold', 'Trackbar')/100
    edge = cv.getTrackbarPos('edge threshold', 'Trackbar')
    sig = cv.getTrackbarPos('sigma', 'Trackbar')/10

    sift = cv.SIFT_create(nOctaveLayers = 3, contrastThreshold = contrast, edgeThreshold = edge, sigma = sig)
    bf = cv.BFMatcher(cv.NORM_L2SQR, crossCheck=True)

    key1, des1 = sift.detectAndCompute(img1_gray, None)
    key5, des5 = sift.detectAndCompute(img5_gray, None)

    matches = bf.match(des1, des5)
    matches = sorted(matches, key=lambda x:x.distance)

    out_img = cv.drawMatches(img1, key1, img5, key5, matches, img5, flags=2)
    # out_img = img1
    print(contrast, edge, sig)

    cv.imshow('Trackbar', out_img)

    if cv.waitKey(1) & 0xFF == 27:
        break


cv.destroyAllWindows()
# Out:
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.1 1 1.0
# 0.09 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 1 1.0
# 0.07 34 1.0
# 0.07 36 1.0
# 0.07 36 1.0
# 0.07 32 1.0
# 0.07 25 1.0
# 0.07 23 1.0
# 0.07 0 1.0
# 0.07 0 1.0
# 0.07 0 1.0
# 0.07 0 1.0
# 0.07 0 1.0
# 0.07 18 1.0
# 0.07 20 1.0
# 0.07 20 1.0
# 0.07 20 1.0
# 0.07 20 1.0
# 0.07 20 1.0
# 0.07 20 1.0
# 0.07 20 1.0
# 0.07 20 1.0
# 0.07 20 1.0
# 0.07 20 0.9
# 0.07 20 0.8
# 0.07 20 0.8
# 0.07 20 0.8
# 0.07 20 0.7
# 0.07 20 0.7
# 0.07 20 0.7
# 0.07 20 0.6
# 0.07 20 0.6
# 0.07 20 0.5
# 0.07 20 0.5
# 0.07 20 0.3
# 0.07 20 0.3
# 0.07 20 0.3
# 0.07 20 0.3
# 0.07 20 0.3
# 0.07 20 0.3
# 0.07 20 0.3
# 0.07 20 0.3
# 0.07 20 0.3
# 0.07 20 0.3
# 0.07 20 0.3
# ...

# %%
car = cv.imread("C:/Users/Dulanjana/Downloads/ferrari-488-white-8k-s0.jpg")
logo = cv.imread("C:/Users/Dulanjana/Downloads/posters-black-horse-silhouette-16.jpg.jpg")

car = cv.cvtColor(car, cv.COLOR_BGR2RGB)


cv.circle(car, (460, 190), 2, (255, 0, 0), cv.FILLED)

fig, ax = plt.subplots(1, 2, figsize=(20, 9))
ax[0].imshow(car)
ax[1].imshow(logo)

plt.show()
